# %%
#Operations on Singly Linked List 
class Node:
    def __init__(self,newData = None,link = None):
        self.data = newData
        self.next = link

class SingleLinkedList:
    def __init__(self):
        self.Head = None

    def insert_end(self,newData):
        newNode = Node(newData)
        if self.Head is None:
            self.Head = newNode

        else:
            curNode = self.Head
            while curNode.next is not None:
                curNode = curNode.next
            curNode.next = newNode

    #Function to insert a node at the beginning of the list
    def insert_begin(self,newData):
        self.Head = Node(newData,self.Head)
        
    #Function to insert a node after nth term
    def insert_before_nth(self,newData,location):
        if self.Head is None or location ==1:
            self.Head = Node(newData,self.Head)
        else:
            curNode = self.Head
            c = 1
            while c < location - 1 and curNode.next is not None:
                c+=1
                curNode = curNode.next
            newNode = Node(newData,curNode.next)
            curNode.next = newNode
            
    #function to insert a node after nth term
    def insertion_after_nth(self,newData,location):
        if self.Head is None:
            self.Head = Node(newData,self.Head)
        else:
            curNode = self.Head
            c = 1
            while c < location and curNode.next is not None:
                c += 1
                curNode = curNode.next
            curNode.next = Node(newData,curNode.next)

    def delete_first(self):
        if self.Head is None:
            print("Empty list. Deletion not possible")
        else:
            curNode = self.Head
            self.Head = self.Head.next
            def(curNode)
            print("Node Deleted Successfully")

    def delete_last(self):
        if self.Head is None:
            print("Empty list. Deletion not Possible")
        elif self.Head.next is None:
            del(self.Head)
            self.Head = None
        else:
            curNode = self.Head
            while curNode.next.next is not None:
                curNode = curNode.next
            del(curNode.next)
            curNode.next = None
            print("Node Deleted Succesfully")

    def delete_anynode(self,num):
        if self.Head is None:
            print("Empty list. Deletion not Possible")
        else:
            curNode = self.Head
            if curNode.data == num:
                self.Head = self.Head.next
                del(curNode)
                print("Node Deleted Successfully")
            else:
                flag = 0
                prev = None
                while curNode is not None:
                    if curNode.data == num:
                        flag = 1
                        break
                    prev = curNode
                    curNode = curNode.next
                if flag == 0:
                    print("Node not found")
                else:
                    prev.next = curNode.next
                    def(curNode)
                    print("Node Deleted Successfully")

    def display(self):
        if self.Head is None:
            print("Empty List")
        else : 
            curNode = self.Head
            while curNode is not None:
                print(curNode.data , end = " ")
                curNode = curNode.next
            print("None")

head = SingleLinkedList()
# Insert some elements
head.insert_end(10)
head.insert_end(20)
head.insert_end(30)

# Display the linked list
head.display()
# Out:
#   Cell In[2], line 57
#     def(curNode)
#        ^
# SyntaxError: invalid syntax

# %%
# Operations on Singly Linked List
class Node:
    def __init__(self, newData=None, link=None):
        self.data = newData
        self.next = link

class SingleLinkedList:
    def __init__(self):
        self.Head = None

    def insert_end(self, newData):
        newNode = Node(newData)
        if self.Head is None:
            self.Head = newNode
        else:
            curNode = self.Head
            while curNode.next is not None:
                curNode = curNode.next
            curNode.next = newNode

    # Function to insert a node at the beginning of the list
    def insert_begin(self, newData):
        self.Head = Node(newData, self.Head)
        
    # Function to insert a node before nth term
    def insert_before_nth(self, newData, location):
        if self.Head is None or location == 1:
            self.Head = Node(newData, self.Head)
        else:
            curNode = self.Head
            c = 1
            while c < location - 1 and curNode.next is not None:
                c += 1
                curNode = curNode.next
            newNode = Node(newData, curNode.next)
            curNode.next = newNode
            
    # Function to insert a node after nth term
    def insertion_after_nth(self, newData, location):
        if self.Head is None:
            self.Head = Node(newData, self.Head)
        else:
            curNode = self.Head
            c = 1
            while c < location and curNode.next is not None:
                c += 1
                curNode = curNode.next
            if curNode is None:  # If location is out of bounds
                print("Invalid location")
                return
            curNode.next = Node(newData, curNode.next)

    def delete_first(self):
        if self.Head is None:
            print("Empty list. Deletion not possible")
        else:
            curNode = self.Head
            self.Head = self.Head.next
            del(curNode)
            print("Node Deleted Successfully")

    def delete_last(self):
        if self.Head is None:
            print("Empty list. Deletion not possible")
        elif self.Head.next is None:
            del(self.Head)
            self.Head = None
            print("Node Deleted Successfully")
        else:
            curNode = self.Head
            while curNode.next and curNode.next.next is not None:
                curNode = curNode.next
            del(curNode.next)
            curNode.next = None
            print("Node Deleted Successfully")

    def delete_anynode(self, num):
        if self.Head is None:
            print("Empty list. Deletion not possible")
        else:
            curNode = self.Head
            if curNode.data == num:
                self.Head = self.Head.next
                del(curNode)
                print("Node Deleted Successfully")
            else:
                flag = 0
                prev = None
                while curNode is not None:
                    if curNode.data == num:
                        flag = 1
                        break
                    prev = curNode
                    curNode = curNode.next
                if flag == 0:
                    print("Node not found")
                else:
                    prev.next = curNode.next
                    del(curNode)
                    print("Node Deleted Successfully")

    def display(self):
        if self.Head is None:
            print("Empty List")
        else:
            curNode = self.Head
            while curNode is not None:
                print(curNode.data, end=" ")
                curNode = curNode.next
            print("None")

# Create Linked List
head = SingleLinkedList()

# Insert elements
head.insert_end(10)
head.insert_end(20)
head.insert_end(30)
print("Linked List after inserting elements at the end:")
head.display()

# Insert an element at the beginning
head.insert_begin(5)
print("Linked List after inserting 5 at the beginning:")
head.display()

# Insert an element before the 2nd position
head.insert_before_nth(15, 2)
print("Linked List after inserting 15 before the 2nd position:")
head.display()

# Insert an element after the 3rd position
head.insertion_after_nth(25, 3)
print("Linked List after inserting 25 after the 3rd position:")
head.display()

# Delete the first element
head.delete_first()
print("Linked List after deleting the first element:")
head.display()

# Delete the last element
head.delete_last()
print("Linked List after deleting the last element:")
head.display()

# Delete a specific node (e.g., delete node with value 20)
head.delete_anynode(20)
print("Linked List after deleting node with value 20:")
head.display()
# Out:
# Linked List after inserting elements at the end:
# 10 20 30 None
# Linked List after inserting 5 at the beginning:
# 5 10 20 30 None
# Linked List after inserting 15 before the 2nd position:
# 5 15 10 20 30 None
# Linked List after inserting 25 after the 3rd position:
# 5 15 10 25 20 30 None
# Node Deleted Successfully
# Linked List after deleting the first element:
# 15 10 25 20 30 None
# Node Deleted Successfully
# Linked List after deleting the last element:
# 15 10 25 20 None
# Node Deleted Successfully
# Linked List after deleting node with value 20:
# 15 10 25 None
